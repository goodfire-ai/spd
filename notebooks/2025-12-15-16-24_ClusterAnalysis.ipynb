# %%
import numpy as np
import json
from pathlib import Path
from collections import defaultdict

ensemble_dir = Path("/mnt/polished-lake/spd/ensemble/e-5f228e5f")

# Load the merge array data
merge_data = np.load(ensemble_dir / "ensemble_merge_array.npz")
merge_array = merge_data['merge_array']  # shape (10, 300, 442)

# Load metadata to get component labels
with open(ensemble_dir / "ensemble_meta.json") as f:
    meta = json.load(f)

print(f"Merge array shape: {merge_array.shape}")
print(f"Number of component labels: {len(meta['component_labels'])}")
print(f"Sample labels: {meta['component_labels'][:5]}")
# Out:
# Merge array shape: (10, 300, 442)
# Number of component labels: 442
# Sample labels: ['h.0.mlp.down_proj:1', 'h.0.mlp.down_proj:10', 'h.0.mlp.down_proj:100', 'h.0.mlp.down_proj:101', 'h.0.mlp.down_proj:102']

# %%
# Get cluster assignments for Run 0 at final iteration (299)
run_idx = 0
iter_idx = 299
assignments = merge_array[run_idx, iter_idx, :]

print(f"Run {run_idx}, Iteration {iter_idx}")
print(f"Number of components: {len(assignments)}")
print(f"Number of unique clusters: {len(np.unique(assignments))}")

# Group components by cluster
clusters = defaultdict(list)
for comp_idx, cluster_id in enumerate(assignments):
    clusters[cluster_id].append(comp_idx)

# Sort clusters by size (descending)
sorted_clusters = sorted(clusters.items(), key=lambda x: -len(x[1]))

print(f"\nCluster sizes (top 10):")
for i, (cluster_id, members) in enumerate(sorted_clusters[:10]):
    print(f"  Cluster {i+1}: {len(members)} components")

print(f"\nTotal clusters: {len(sorted_clusters)}")
# Out:
# Run 0, Iteration 299
# Number of components: 442
# Number of unique clusters: 142
#
# Cluster sizes (top 10):
#   Cluster 1: 68 components
#   Cluster 2: 16 components
#   Cluster 3: 14 components
#   Cluster 4: 11 components
#   Cluster 5: 10 components
#   Cluster 6: 8 components
#   Cluster 7: 8 components
#   Cluster 8: 7 components
#   Cluster 9: 6 components
#   Cluster 10: 6 components
#
# Total clusters: 142

# %%
# Output all clusters with their raw component indices, ordered by size
# Also include neuron indices from labels for reference

component_labels = meta['component_labels']

def parse_neuron_idx(label):
    """Parse 'h.0.mlp.down_proj:N' to get neuron index N"""
    return int(label.split(':')[1])

neuron_indices = [parse_neuron_idx(l) for l in component_labels]

print("=" * 80)
print("CLUSTER ASSIGNMENTS FOR RUN 0, ITERATION 299")
print("=" * 80)
print(f"\nTotal: 442 components in 142 clusters")
print(f"Component indices are 0-indexed positions in the merge array")
print(f"Neuron indices are the original MLP neuron IDs (from 'h.0.mlp.down_proj:N')")
print("\n")

for rank, (cluster_id, members) in enumerate(sorted_clusters):
    neuron_ids = [neuron_indices[m] for m in members]
    print(f"Cluster {rank + 1} (size {len(members)}):")
    print(f"  Raw component indices: {sorted(members)}")
    print(f"  Neuron indices: {sorted(neuron_ids)}")
    print()
# Out:
# ================================================================================
# CLUSTER ASSIGNMENTS FOR RUN 0, ITERATION 299
# ================================================================================
#
# Total: 442 components in 142 clusters
# Component indices are 0-indexed positions in the merge array
# Neuron indices are the original MLP neuron IDs (from 'h.0.mlp.down_proj:N')
#
#
# Cluster 1 (size 68):
#   Raw component indices: [5, 13, 21, 27, 32, 35, 44, 48, 52, 64, 85, 91, 98, 100, 103, 108, 109, 110, 111, 114, 118, 121, 136, 138, 144, 150, 163, 172, 178, 183, 185, 197, 213, 216, 220, 232, 238, 240, 241, 242, 254, 262, 263, 274, 283, 284, 287, 304, 308, 313, 318, 319, 331, 335, 338, 344, 358, 367, 379, 380, 383, 388, 399, 411, 415, 421, 422, 436]
#   Neuron indices: [5, 6, 17, 24, 33, 38, 54, 60, 63, 65, 71, 73, 93, 103, 115, 128, 134, 140, 143, 155, 163, 184, 210, 219, 230, 232, 235, 240, 241, 244, 247, 251, 255, 277, 279, 287, 297, 310, 324, 336, 339, 354, 384, 388, 401, 408, 410, 411, 412, 427, 437, 439, 453, 465, 467, 472, 495, 505, 512, 513, 528, 537, 549, 570, 584, 602, 608, 643]
#
# Cluster 2 (size 16):
#   Raw component indices: [49, 53, 55, 97, 125, 128, 143, 199, 259, 261, 295, 323, 332, 382, 393, 435]
#   Neuron indices: [23, 26, 53, 90, 165, 170, 172, 262, 286, 358, 433, 436, 482, 517, 601, 620]
#
# Cluster 3 (size 14):
#   Raw component indices: [24, 54, 65, 83, 139, 147, 173, 251, 300, 336, 365, 402, 403, 437]
#   Neuron indices: [28, 95, 130, 171, 185, 205, 292, 325, 424, 490, 538, 582, 632, 633]
#
# Cluster 4 (size 11):
#   Raw component indices: [10, 45, 94, 131, 198, 246, 280, 292, 301, 330, 414]
#   Neuron indices: [42, 109, 159, 225, 269, 357, 461, 478, 491, 526, 648]
#
# Cluster 5 (size 10):
#   Raw component indices: [57, 62, 89, 137, 200, 219, 239, 276, 291, 298]
#   Neuron indices: [175, 180, 217, 278, 359, 387, 409, 456, 477, 489]
#
# Cluster 6 (size 8):
#   Raw component indices: [17, 47, 107, 140, 228, 314, 324, 355]
#   Neuron indices: [121, 162, 239, 281, 397, 507, 518, 564]
#
# Cluster 7 (size 8):
#   Raw component indices: [86, 176, 207, 249, 385, 410, 426, 430]
#   Neuron indices: [77, 84, 211, 328, 367, 422, 604, 642]
#
# Cluster 8 (size 7):
#   Raw component indices: [0, 42, 46, 169, 191, 230, 290]
#   Neuron indices: [1, 4, 152, 160, 319, 348, 476]
#
# Cluster 9 (size 6):
#   Raw component indices: [7, 92, 165, 188, 189, 208]
#   Neuron indices: [22, 105, 314, 343, 344, 369]
#
# Cluster 10 (size 6):
#   Raw component indices: [19, 171, 193, 269, 376, 416]
#   Neuron indices: [35, 66, 125, 321, 448, 596]
#
# Cluster 11 (size 6):
#   Raw component indices: [30, 184, 203, 296, 362, 408]
#   Neuron indices: [64, 138, 338, 363, 483, 579]
#
# Cluster 12 (size 6):
#   Raw component indices: [93, 159, 209, 210, 326, 428]
#   Neuron indices: [80, 220, 306, 372, 376, 522]
#
# Cluster 13 (size 5):
#   Raw component indices: [14, 132, 212, 288, 396]
#   Neuron indices: [27, 116, 379, 473, 625]
#
# Cluster 14 (size 5):
#   Raw component indices: [76, 106, 206, 215, 359]
#   Neuron indices: [2, 238, 366, 381, 575]
#
# Cluster 15 (size 5):
#   Raw component indices: [96, 225, 302, 429, 440]
#   Neuron indices: [82, 98, 228, 393, 492]
#
# Cluster 16 (size 5):
#   Raw component indices: [146, 180, 257, 278, 394]
#   Neuron indices: [29, 332, 431, 459, 622]
#
# Cluster 17 (size 5):
#   Raw component indices: [187, 202, 266, 321, 431]
#   Neuron indices: [86, 340, 362, 444, 515]
#
# Cluster 18 (size 4):
#   Raw component indices: [1, 174, 363, 381]
#   Neuron indices: [10, 58, 326, 600]
#
# Cluster 19 (size 4):
#   Raw component indices: [9, 63, 334, 349]
#   Neuron indices: [108, 182, 534, 557]
#
# Cluster 20 (size 4):
#   Raw component indices: [23, 123, 231, 305]
#   Neuron indices: [13, 40, 257, 497]
#
# Cluster 21 (size 4):
#   Raw component indices: [26, 87, 390, 400]
#   Neuron indices: [132, 215, 613, 630]
#
# Cluster 22 (size 4):
#   Raw component indices: [28, 170, 175, 317]
#   Neuron indices: [32, 136, 327, 511]
#
# Cluster 23 (size 4):
#   Raw component indices: [34, 244, 260, 267]
#   Neuron indices: [142, 417, 434, 445]
#
# Cluster 24 (size 4):
#   Raw component indices: [36, 113, 285, 315]
#   Neuron indices: [144, 246, 470, 508]
#
# Cluster 25 (size 4):
#   Raw component indices: [61, 268, 374, 425]
#   Neuron indices: [18, 76, 447, 592]
#
# Cluster 26 (size 4):
#   Raw component indices: [67, 204, 384, 398]
#   Neuron indices: [187, 364, 603, 628]
#
# Cluster 27 (size 4):
#   Raw component indices: [124, 250, 339, 354]
#   Neuron indices: [259, 423, 540, 563]
#
# Cluster 28 (size 4):
#   Raw component indices: [151, 156, 223, 412]
#   Neuron indices: [299, 303, 391, 644]
#
# Cluster 29 (size 4):
#   Raw component indices: [162, 275, 348, 389]
#   Neuron indices: [31, 455, 556, 612]
#
# Cluster 30 (size 3):
#   Raw component indices: [2, 227, 340]
#   Neuron indices: [100, 395, 541]
#
# Cluster 31 (size 3):
#   Raw component indices: [4, 356, 438]
#   Neuron indices: [96, 102, 565]
#
# Cluster 32 (size 3):
#   Raw component indices: [18, 157, 439]
#   Neuron indices: [97, 123, 304]
#
# Cluster 33 (size 3):
#   Raw component indices: [22, 77, 135]
#   Neuron indices: [20, 129, 276]
#
# Cluster 34 (size 3):
#   Raw component indices: [37, 192, 211]
#   Neuron indices: [147, 349, 377]
#
# Cluster 35 (size 3):
#   Raw component indices: [50, 352, 361]
#   Neuron indices: [56, 167, 577]
#
# Cluster 36 (size 3):
#   Raw component indices: [51, 142, 377]
#   Neuron indices: [169, 284, 597]
#
# Cluster 37 (size 3):
#   Raw component indices: [58, 369, 409]
#   Neuron indices: [176, 586, 641]
#
# Cluster 38 (size 3):
#   Raw component indices: [59, 148, 152]
#   Neuron indices: [3, 178, 294]
#
# Cluster 39 (size 3):
#   Raw component indices: [68, 214, 310]
#   Neuron indices: [188, 380, 501]
#
# Cluster 40 (size 3):
#   Raw component indices: [71, 229, 386]
#   Neuron indices: [193, 399, 605]
#
# Cluster 41 (size 3):
#   Raw component indices: [78, 341, 401]
#   Neuron indices: [200, 543, 631]
#
# Cluster 42 (size 3):
#   Raw component indices: [84, 325, 419]
#   Neuron indices: [7, 52, 209]
#
# Cluster 43 (size 3):
#   Raw component indices: [90, 160, 256]
#   Neuron indices: [43, 218, 308]
#
# Cluster 44 (size 3):
#   Raw component indices: [141, 270, 286]
#   Neuron indices: [282, 449, 471]
#
# Cluster 45 (size 3):
#   Raw component indices: [145, 303, 370]
#   Neuron indices: [289, 494, 587]
#
# Cluster 46 (size 3):
#   Raw component indices: [149, 307, 373]
#   Neuron indices: [59, 295, 499]
#
# Cluster 47 (size 3):
#   Raw component indices: [155, 222, 265]
#   Neuron indices: [302, 390, 443]
#
# Cluster 48 (size 3):
#   Raw component indices: [164, 226, 351]
#   Neuron indices: [311, 394, 559]
#
# Cluster 49 (size 3):
#   Raw component indices: [177, 264, 299]
#   Neuron indices: [49, 329, 441]
#
# Cluster 50 (size 3):
#   Raw component indices: [181, 312, 346]
#   Neuron indices: [333, 503, 550]
#
# Cluster 51 (size 3):
#   Raw component indices: [196, 235, 253]
#   Neuron indices: [352, 404, 426]
#
# Cluster 52 (size 3):
#   Raw component indices: [201, 345, 378]
#   Neuron indices: [55, 361, 598]
#
# Cluster 53 (size 3):
#   Raw component indices: [333, 360, 433]
#   Neuron indices: [89, 533, 576]
#
# Cluster 54 (size 2):
#   Raw component indices: [6, 11]
#   Neuron indices: [104, 113]
#
# Cluster 55 (size 2):
#   Raw component indices: [12, 434]
#   Neuron indices: [9, 114]
#
# Cluster 56 (size 2):
#   Raw component indices: [15, 179]
#   Neuron indices: [119, 330]
#
# Cluster 57 (size 2):
#   Raw component indices: [16, 271]
#   Neuron indices: [12, 45]
#
# Cluster 58 (size 2):
#   Raw component indices: [25, 395]
#   Neuron indices: [131, 623]
#
# Cluster 59 (size 2):
#   Raw component indices: [29, 407]
#   Neuron indices: [137, 639]
#
# Cluster 60 (size 2):
#   Raw component indices: [31, 126]
#   Neuron indices: [14, 260]
#
# Cluster 61 (size 2):
#   Raw component indices: [33, 217]
#   Neuron indices: [141, 385]
#
# Cluster 62 (size 2):
#   Raw component indices: [38, 99]
#   Neuron indices: [148, 231]
#
# Cluster 63 (size 2):
#   Raw component indices: [39, 427]
#   Neuron indices: [8, 149]
#
# Cluster 64 (size 2):
#   Raw component indices: [40, 224]
#   Neuron indices: [15, 392]
#
# Cluster 65 (size 2):
#   Raw component indices: [69, 195]
#   Neuron indices: [189, 351]
#
# Cluster 66 (size 2):
#   Raw component indices: [70, 328]
#   Neuron indices: [191, 524]
#
# Cluster 67 (size 2):
#   Raw component indices: [74, 245]
#   Neuron indices: [196, 419]
#
# Cluster 68 (size 2):
#   Raw component indices: [75, 371]
#   Neuron indices: [197, 588]
#
# Cluster 69 (size 2):
#   Raw component indices: [80, 258]
#   Neuron indices: [202, 432]
#
# Cluster 70 (size 2):
#   Raw component indices: [81, 101]
#   Neuron indices: [203, 233]
#
# Cluster 71 (size 2):
#   Raw component indices: [112, 186]
#   Neuron indices: [34, 245]
#
# Cluster 72 (size 2):
#   Raw component indices: [115, 243]
#   Neuron indices: [248, 415]
#
# Cluster 73 (size 2):
#   Raw component indices: [119, 205]
#   Neuron indices: [253, 365]
#
# Cluster 74 (size 2):
#   Raw component indices: [122, 353]
#   Neuron indices: [256, 562]
#
# Cluster 75 (size 2):
#   Raw component indices: [127, 350]
#   Neuron indices: [261, 558]
#
# Cluster 76 (size 2):
#   Raw component indices: [154, 322]
#   Neuron indices: [301, 516]
#
# Cluster 77 (size 2):
#   Raw component indices: [158, 166]
#   Neuron indices: [305, 315]
#
# Cluster 78 (size 2):
#   Raw component indices: [161, 424]
#   Neuron indices: [75, 309]
#
# Cluster 79 (size 2):
#   Raw component indices: [167, 343]
#   Neuron indices: [316, 547]
#
# Cluster 80 (size 2):
#   Raw component indices: [168, 309]
#   Neuron indices: [50, 317]
#
# Cluster 81 (size 2):
#   Raw component indices: [182, 413]
#   Neuron indices: [335, 647]
#
# Cluster 82 (size 2):
#   Raw component indices: [190, 289]
#   Neuron indices: [346, 475]
#
# Cluster 83 (size 2):
#   Raw component indices: [194, 277]
#   Neuron indices: [350, 457]
#
# Cluster 84 (size 2):
#   Raw component indices: [221, 368]
#   Neuron indices: [389, 585]
#
# Cluster 85 (size 2):
#   Raw component indices: [234, 297]
#   Neuron indices: [403, 484]
#
# Cluster 86 (size 2):
#   Raw component indices: [237, 391]
#   Neuron indices: [407, 618]
#
# Cluster 87 (size 2):
#   Raw component indices: [248, 320]
#   Neuron indices: [421, 514]
#
# Cluster 88 (size 2):
#   Raw component indices: [273, 306]
#   Neuron indices: [452, 498]
#
# Cluster 89 (size 2):
#   Raw component indices: [282, 406]
#   Neuron indices: [463, 637]
#
# Cluster 90 (size 2):
#   Raw component indices: [294, 387]
#   Neuron indices: [481, 607]
#
# Cluster 91 (size 2):
#   Raw component indices: [316, 342]
#   Neuron indices: [510, 544]
#
# Cluster 92 (size 2):
#   Raw component indices: [327, 375]
#   Neuron indices: [523, 595]
#
# Cluster 93 (size 2):
#   Raw component indices: [329, 337]
#   Neuron indices: [525, 539]
#
# Cluster 94 (size 2):
#   Raw component indices: [364, 418]
#   Neuron indices: [68, 580]
#
# Cluster 95 (size 2):
#   Raw component indices: [397, 417]
#   Neuron indices: [67, 627]
#
# Cluster 96 (size 1):
#   Raw component indices: [3]
#   Neuron indices: [101]
#
# Cluster 97 (size 1):
#   Raw component indices: [8]
#   Neuron indices: [106]
#
# Cluster 98 (size 1):
#   Raw component indices: [20]
#   Neuron indices: [127]
#
# Cluster 99 (size 1):
#   Raw component indices: [41]
#   Neuron indices: [150]
#
# Cluster 100 (size 1):
#   Raw component indices: [43]
#   Neuron indices: [153]
#
# Cluster 101 (size 1):
#   Raw component indices: [56]
#   Neuron indices: [173]
#
# Cluster 102 (size 1):
#   Raw component indices: [60]
#   Neuron indices: [179]
#
# Cluster 103 (size 1):
#   Raw component indices: [66]
#   Neuron indices: [186]
#
# Cluster 104 (size 1):
#   Raw component indices: [72]
#   Neuron indices: [194]
#
# Cluster 105 (size 1):
#   Raw component indices: [73]
#   Neuron indices: [195]
#
# Cluster 106 (size 1):
#   Raw component indices: [79]
#   Neuron indices: [201]
#
# Cluster 107 (size 1):
#   Raw component indices: [82]
#   Neuron indices: [204]
#
# Cluster 108 (size 1):
#   Raw component indices: [88]
#   Neuron indices: [216]
#
# Cluster 109 (size 1):
#   Raw component indices: [95]
#   Neuron indices: [227]
#
# Cluster 110 (size 1):
#   Raw component indices: [102]
#   Neuron indices: [234]
#
# Cluster 111 (size 1):
#   Raw component indices: [104]
#   Neuron indices: [236]
#
# Cluster 112 (size 1):
#   Raw component indices: [105]
#   Neuron indices: [237]
#
# Cluster 113 (size 1):
#   Raw component indices: [116]
#   Neuron indices: [25]
#
# Cluster 114 (size 1):
#   Raw component indices: [117]
#   Neuron indices: [250]
#
# Cluster 115 (size 1):
#   Raw component indices: [120]
#   Neuron indices: [254]
#
# Cluster 116 (size 1):
#   Raw component indices: [129]
#   Neuron indices: [266]
#
# Cluster 117 (size 1):
#   Raw component indices: [130]
#   Neuron indices: [267]
#
# Cluster 118 (size 1):
#   Raw component indices: [133]
#   Neuron indices: [272]
#
# Cluster 119 (size 1):
#   Raw component indices: [134]
#   Neuron indices: [273]
#
# Cluster 120 (size 1):
#   Raw component indices: [153]
#   Neuron indices: [300]
#
# Cluster 121 (size 1):
#   Raw component indices: [218]
#   Neuron indices: [386]
#
# Cluster 122 (size 1):
#   Raw component indices: [233]
#   Neuron indices: [402]
#
# Cluster 123 (size 1):
#   Raw component indices: [236]
#   Neuron indices: [405]
#
# Cluster 124 (size 1):
#   Raw component indices: [247]
#   Neuron indices: [420]
#
# Cluster 125 (size 1):
#   Raw component indices: [252]
#   Neuron indices: [425]
#
# Cluster 126 (size 1):
#   Raw component indices: [255]
#   Neuron indices: [428]
#
# Cluster 127 (size 1):
#   Raw component indices: [272]
#   Neuron indices: [451]
#
# Cluster 128 (size 1):
#   Raw component indices: [279]
#   Neuron indices: [46]
#
# Cluster 129 (size 1):
#   Raw component indices: [281]
#   Neuron indices: [462]
#
# Cluster 130 (size 1):
#   Raw component indices: [293]
#   Neuron indices: [48]
#
# Cluster 131 (size 1):
#   Raw component indices: [311]
#   Neuron indices: [502]
#
# Cluster 132 (size 1):
#   Raw component indices: [347]
#   Neuron indices: [555]
#
# Cluster 133 (size 1):
#   Raw component indices: [357]
#   Neuron indices: [566]
#
# Cluster 134 (size 1):
#   Raw component indices: [366]
#   Neuron indices: [583]
#
# Cluster 135 (size 1):
#   Raw component indices: [372]
#   Neuron indices: [589]
#
# Cluster 136 (size 1):
#   Raw component indices: [392]
#   Neuron indices: [62]
#
# Cluster 137 (size 1):
#   Raw component indices: [404]
#   Neuron indices: [635]
#
# Cluster 138 (size 1):
#   Raw component indices: [405]
#   Neuron indices: [636]
#
# Cluster 139 (size 1):
#   Raw component indices: [420]
#   Neuron indices: [70]
#
# Cluster 140 (size 1):
#   Raw component indices: [423]
#   Neuron indices: [74]
#
# Cluster 141 (size 1):
#   Raw component indices: [432]
#   Neuron indices: [88]
#
# Cluster 142 (size 1):
#   Raw component indices: [441]
#   Neuron indices: [99]

# %%
# Compact output: just raw component indices per cluster
print("CLUSTERS BY SIZE (raw component indices 0-441):")
print("=" * 60)
for rank, (cluster_id, members) in enumerate(sorted_clusters):
    print(f"Cluster {rank + 1:3d} (n={len(members):2d}): {sorted(members)}")
# Out:
# CLUSTERS BY SIZE (raw component indices 0-441):
# ============================================================
# Cluster   1 (n=68): [5, 13, 21, 27, 32, 35, 44, 48, 52, 64, 85, 91, 98, 100, 103, 108, 109, 110, 111, 114, 118, 121, 136, 138, 144, 150, 163, 172, 178, 183, 185, 197, 213, 216, 220, 232, 238, 240, 241, 242, 254, 262, 263, 274, 283, 284, 287, 304, 308, 313, 318, 319, 331, 335, 338, 344, 358, 367, 379, 380, 383, 388, 399, 411, 415, 421, 422, 436]
# Cluster   2 (n=16): [49, 53, 55, 97, 125, 128, 143, 199, 259, 261, 295, 323, 332, 382, 393, 435]
# Cluster   3 (n=14): [24, 54, 65, 83, 139, 147, 173, 251, 300, 336, 365, 402, 403, 437]
# Cluster   4 (n=11): [10, 45, 94, 131, 198, 246, 280, 292, 301, 330, 414]
# Cluster   5 (n=10): [57, 62, 89, 137, 200, 219, 239, 276, 291, 298]
# Cluster   6 (n= 8): [17, 47, 107, 140, 228, 314, 324, 355]
# Cluster   7 (n= 8): [86, 176, 207, 249, 385, 410, 426, 430]
# Cluster   8 (n= 7): [0, 42, 46, 169, 191, 230, 290]
# Cluster   9 (n= 6): [7, 92, 165, 188, 189, 208]
# Cluster  10 (n= 6): [19, 171, 193, 269, 376, 416]
# Cluster  11 (n= 6): [30, 184, 203, 296, 362, 408]
# Cluster  12 (n= 6): [93, 159, 209, 210, 326, 428]
# Cluster  13 (n= 5): [14, 132, 212, 288, 396]
# Cluster  14 (n= 5): [76, 106, 206, 215, 359]
# Cluster  15 (n= 5): [96, 225, 302, 429, 440]
# Cluster  16 (n= 5): [146, 180, 257, 278, 394]
# Cluster  17 (n= 5): [187, 202, 266, 321, 431]
# Cluster  18 (n= 4): [1, 174, 363, 381]
# Cluster  19 (n= 4): [9, 63, 334, 349]
# Cluster  20 (n= 4): [23, 123, 231, 305]
# Cluster  21 (n= 4): [26, 87, 390, 400]
# Cluster  22 (n= 4): [28, 170, 175, 317]
# Cluster  23 (n= 4): [34, 244, 260, 267]
# Cluster  24 (n= 4): [36, 113, 285, 315]
# Cluster  25 (n= 4): [61, 268, 374, 425]
# Cluster  26 (n= 4): [67, 204, 384, 398]
# Cluster  27 (n= 4): [124, 250, 339, 354]
# Cluster  28 (n= 4): [151, 156, 223, 412]
# Cluster  29 (n= 4): [162, 275, 348, 389]
# Cluster  30 (n= 3): [2, 227, 340]
# Cluster  31 (n= 3): [4, 356, 438]
# Cluster  32 (n= 3): [18, 157, 439]
# Cluster  33 (n= 3): [22, 77, 135]
# Cluster  34 (n= 3): [37, 192, 211]
# Cluster  35 (n= 3): [50, 352, 361]
# Cluster  36 (n= 3): [51, 142, 377]
# Cluster  37 (n= 3): [58, 369, 409]
# Cluster  38 (n= 3): [59, 148, 152]
# Cluster  39 (n= 3): [68, 214, 310]
# Cluster  40 (n= 3): [71, 229, 386]
# Cluster  41 (n= 3): [78, 341, 401]
# Cluster  42 (n= 3): [84, 325, 419]
# Cluster  43 (n= 3): [90, 160, 256]
# Cluster  44 (n= 3): [141, 270, 286]
# Cluster  45 (n= 3): [145, 303, 370]
# Cluster  46 (n= 3): [149, 307, 373]
# Cluster  47 (n= 3): [155, 222, 265]
# Cluster  48 (n= 3): [164, 226, 351]
# Cluster  49 (n= 3): [177, 264, 299]
# Cluster  50 (n= 3): [181, 312, 346]
# Cluster  51 (n= 3): [196, 235, 253]
# Cluster  52 (n= 3): [201, 345, 378]
# Cluster  53 (n= 3): [333, 360, 433]
# Cluster  54 (n= 2): [6, 11]
# Cluster  55 (n= 2): [12, 434]
# Cluster  56 (n= 2): [15, 179]
# Cluster  57 (n= 2): [16, 271]
# Cluster  58 (n= 2): [25, 395]
# Cluster  59 (n= 2): [29, 407]
# Cluster  60 (n= 2): [31, 126]
# Cluster  61 (n= 2): [33, 217]
# Cluster  62 (n= 2): [38, 99]
# Cluster  63 (n= 2): [39, 427]
# Cluster  64 (n= 2): [40, 224]
# Cluster  65 (n= 2): [69, 195]
# Cluster  66 (n= 2): [70, 328]
# Cluster  67 (n= 2): [74, 245]
# Cluster  68 (n= 2): [75, 371]
# Cluster  69 (n= 2): [80, 258]
# Cluster  70 (n= 2): [81, 101]
# Cluster  71 (n= 2): [112, 186]
# Cluster  72 (n= 2): [115, 243]
# Cluster  73 (n= 2): [119, 205]
# Cluster  74 (n= 2): [122, 353]
# Cluster  75 (n= 2): [127, 350]
# Cluster  76 (n= 2): [154, 322]
# Cluster  77 (n= 2): [158, 166]
# Cluster  78 (n= 2): [161, 424]
# Cluster  79 (n= 2): [167, 343]
# Cluster  80 (n= 2): [168, 309]
# Cluster  81 (n= 2): [182, 413]
# Cluster  82 (n= 2): [190, 289]
# Cluster  83 (n= 2): [194, 277]
# Cluster  84 (n= 2): [221, 368]
# Cluster  85 (n= 2): [234, 297]
# Cluster  86 (n= 2): [237, 391]
# Cluster  87 (n= 2): [248, 320]
# Cluster  88 (n= 2): [273, 306]
# Cluster  89 (n= 2): [282, 406]
# Cluster  90 (n= 2): [294, 387]
# Cluster  91 (n= 2): [316, 342]
# Cluster  92 (n= 2): [327, 375]
# Cluster  93 (n= 2): [329, 337]
# Cluster  94 (n= 2): [364, 418]
# Cluster  95 (n= 2): [397, 417]
# Cluster  96 (n= 1): [3]
# Cluster  97 (n= 1): [8]
# Cluster  98 (n= 1): [20]
# Cluster  99 (n= 1): [41]
# Cluster 100 (n= 1): [43]
# Cluster 101 (n= 1): [56]
# Cluster 102 (n= 1): [60]
# Cluster 103 (n= 1): [66]
# Cluster 104 (n= 1): [72]
# Cluster 105 (n= 1): [73]
# Cluster 106 (n= 1): [79]
# Cluster 107 (n= 1): [82]
# Cluster 108 (n= 1): [88]
# Cluster 109 (n= 1): [95]
# Cluster 110 (n= 1): [102]
# Cluster 111 (n= 1): [104]
# Cluster 112 (n= 1): [105]
# Cluster 113 (n= 1): [116]
# Cluster 114 (n= 1): [117]
# Cluster 115 (n= 1): [120]
# Cluster 116 (n= 1): [129]
# Cluster 117 (n= 1): [130]
# Cluster 118 (n= 1): [133]
# Cluster 119 (n= 1): [134]
# Cluster 120 (n= 1): [153]
# Cluster 121 (n= 1): [218]
# Cluster 122 (n= 1): [233]
# Cluster 123 (n= 1): [236]
# Cluster 124 (n= 1): [247]
# Cluster 125 (n= 1): [252]
# Cluster 126 (n= 1): [255]
# Cluster 127 (n= 1): [272]
# Cluster 128 (n= 1): [279]
# Cluster 129 (n= 1): [281]
# Cluster 130 (n= 1): [293]
# Cluster 131 (n= 1): [311]
# Cluster 132 (n= 1): [347]
# Cluster 133 (n= 1): [357]
# Cluster 134 (n= 1): [366]
# Cluster 135 (n= 1): [372]
# Cluster 136 (n= 1): [392]
# Cluster 137 (n= 1): [404]
# Cluster 138 (n= 1): [405]
# Cluster 139 (n= 1): [420]
# Cluster 140 (n= 1): [423]
# Cluster 141 (n= 1): [432]
# Cluster 142 (n= 1): [441]

# %%
# Summary statistics
print("\nSUMMARY:")
print(f"  Total components: 442")
print(f"  Total clusters: 142")
print(f"  Largest cluster: 68 components (15.4% of total)")
print(f"  Singletons: 47 clusters")
print(f"  Multi-component clusters: 95")
print(f"\nCluster size distribution:")
size_counts = {}
for _, members in sorted_clusters:
    size = len(members)
    size_counts[size] = size_counts.get(size, 0) + 1
for size in sorted(size_counts.keys(), reverse=True):
    print(f"  Size {size:2d}: {size_counts[size]} cluster(s)")
# Out:
# SUMMARY:
#   Total components: 442
#   Total clusters: 142
#   Largest cluster: 68 components (15.4% of total)
#   Singletons: 47 clusters
#   Multi-component clusters: 95
#
# Cluster size distribution:
#   Size 68: 1 cluster(s)
#   Size 16: 1 cluster(s)
#   Size 14: 1 cluster(s)
#   Size 11: 1 cluster(s)
#   Size 10: 1 cluster(s)
#   Size  8: 2 cluster(s)
#   Size  7: 1 cluster(s)
#   Size  6: 4 cluster(s)
#   Size  5: 5 cluster(s)
#   Size  4: 12 cluster(s)
#   Size  3: 24 cluster(s)
#   Size  2: 42 cluster(s)
#   Size  1: 47 cluster(s)
